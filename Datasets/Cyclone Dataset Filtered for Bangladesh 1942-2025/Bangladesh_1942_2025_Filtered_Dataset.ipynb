# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ibtracs.NI.list.v04r01.csv', low_memory=False)
df
# Out:
#                  SID SEASON NUMBER BASIN SUBBASIN     NAME  \
# 0                      Year
# 1      1842298N11080   1842      1    NI       BB  UNNAMED
# 2      1842298N11080   1842      1    NI       BB  UNNAMED
# 3      1842298N11080   1842      1    NI       BB  UNNAMED
# 4      1842298N11080   1842      1    NI       BB  UNNAMED
# ...              ...    ...    ...   ...      ...      ...
# 62477  2025331N07081   2025    103    NI       BB   DITWAH
# 62478  2025331N07081   2025    103    NI       BB   DITWAH
# 62479  2025331N07081   2025    103    NI       BB   DITWAH
# 62480  2025331N07081   2025    103    NI       BB   DITWAH
# 62481  2025331N07081   2025    103    NI       BB   DITWAH
#
#                   ISO_TIME NATURE            LAT           LON  ...  \
# 0                                  degrees_north  degrees_east  ...
# 1      1842-10-25 03:00:00     NR           10.9          80.3  ...
# 2      1842-10-25 06:00:00     NR           10.9          79.8  ...
# 3      1842-10-25 09:00:00     NR           10.8          79.4  ...
# 4      1842-10-25 12:00:00     NR           10.8          78.9  ...
# ...                    ...    ...            ...           ...  ...
# 62477  2025-12-02 00:00:00     NR           12.5          80.6  ...
# 62478  2025-12-02 03:00:00     NR           12.4          80.8  ...
# 62479  2025-12-02 06:00:00     NR           12.3          80.9  ...
# 62480  2025-12-02 09:00:00     NR           12.2          80.8  ...
# 62481  2025-12-02 12:00:00     NR           12.2          80.6  ...
#
#       BOM_GUST_PER REUNION_GUST REUNION_GUST_PER USA_SEAHGT USA_SEARAD_NE  \
# 0           second          kts           second         ft         nmile
# 1
# 2
# 3
# 4
# ...            ...          ...              ...        ...           ...
# 62477
# 62478
# 62479
# 62480
# 62481
#
#       USA_SEARAD_SE USA_SEARAD_SW USA_SEARAD_NW STORM_SPEED STORM_DIR
# 0             nmile         nmile         nmile         kts   degrees
# 1                                                         9       265
# 2                                                         9       265
# 3                                                         9       265
# 4                                                         9       265
# ...             ...           ...           ...         ...       ...
# 62477                                                     2       130
# 62478                                                     4       125
# 62479                                                     2       160
# 62480                                                     3       250
# 62481                                                     4       260
#
# [62482 rows x 174 columns]

# %%
CORE_COLUMNS = [
    'SID', 'SEASON', 'NUMBER', 'BASIN', 'SUBBASIN', 'NAME',
    'ISO_TIME', 'NATURE', 'LAT', 'LON', 'WMO_WIND', 'WMO_PRES',
    'WMO_AGENCY', 'TRACK_TYPE', 'DIST2LAND', 'LANDFALL', 'IFLAG'
]

# %%
df['BASIN'] = df['BASIN'].astype(str).str.strip().str.upper()
df['SUBBASIN'] = df['SUBBASIN'].astype(str).str.strip().str.upper()
df_filtered = df[(df['BASIN'] == 'NI') & (df['SUBBASIN'] == 'BB')].copy()
df_processed = df_filtered[CORE_COLUMNS].copy()

# %%
df_processed['LAT'] = pd.to_numeric(df_processed['LAT'], errors='coerce')
df_processed['LON'] = pd.to_numeric(df_processed['LON'], errors='coerce')
df_processed['ISO_TIME'] = pd.to_datetime(df_processed['ISO_TIME'], errors='coerce')
df_processed.dropna(subset=['LAT', 'LON', 'ISO_TIME'], inplace=True)

# %%
df_processed['LAT_rad'] = np.radians(df_processed['LAT'])
df_processed['LON_rad'] = np.radians(df_processed['LON'])
df_processed['prev_LAT_rad'] = df_processed.groupby('SID')['LAT_rad'].shift(1)
df_processed['prev_LON_rad'] = df_processed.groupby('SID')['LON_rad'].shift(1)
df_processed.dropna(subset=['prev_LAT_rad', 'prev_LON_rad'], inplace=True)

R = 6371.0
def haversine_distance(lat1, lon1, lat2, lon2):
    dlon = lon2 - lon1
    dlat = lat2 - lat1
    a = np.sin(dlat / 2)**2 + np.cos(lat1) * np.cos(lat2) * np.sin(dlon / 2)**2
    c = 2 * np.arctan2(np.sqrt(a), np.sqrt(1 - a))
    return R * c
df_processed['Haversine Distance'] = haversine_distance(df_processed['prev_LAT_rad'], df_processed['prev_LON_rad'], df_processed['LAT_rad'], df_processed['LON_rad'])
df_processed.drop(columns=['LAT_rad', 'LON_rad', 'prev_LAT_rad', 'prev_LON_rad'], inplace=True)

# %%
df_processed['NAME'] = df_processed['NAME'].fillna('UNNAMED')

# %%
LAT_MIN, LAT_MAX, LON_MIN, LON_MAX = 20.0, 25.0, 87.0, 93.0
df_bangladesh_area = df_processed[
    (df_processed['LAT'] >= LAT_MIN) & (df_processed['LAT'] <= LAT_MAX) &
    (df_processed['LON'] >= LON_MIN) & (df_processed['LON'] <= LON_MAX)
].copy()

# %%
output_filename = 'bangladesh_cyclones_historical.csv'
df_bangladesh_area.to_csv(output_filename, index=False)

print(f"Historical dataset (1842-2025) for Bangladesh Area saved as: {output_filename}")
print(f"Total rows in the historical dataset: {len(df_bangladesh_area)}")
# Out:
# Historical dataset (1842-2025) for Bangladesh Area saved as: bangladesh_cyclones_historical.csv
# Total rows in the historical dataset: 6714

# %%
data = pd.read_csv("/content/bangladesh_cyclones_historical.csv")
data
# Out:
#                 SID  SEASON  NUMBER BASIN SUBBASIN     NAME  \
# 0     1877135N10083    1877      14    NI       BB  UNNAMED
# 1     1877135N10083    1877      14    NI       BB  UNNAMED
# 2     1877135N10083    1877      14    NI       BB  UNNAMED
# 3     1877135N10083    1877      14    NI       BB  UNNAMED
# 4     1877135N10083    1877      14    NI       BB  UNNAMED
# ...             ...     ...     ...   ...      ...      ...
# 6709  2024258N22091    2024      62    NI       BB  UNNAMED
# 6710  2024258N22091    2024      62    NI       BB  UNNAMED
# 6711  2024295N15092    2024      85    NI       BB     DANA
# 6712  2024295N15092    2024      85    NI       BB     DANA
# 6713  2024295N15092    2024      85    NI       BB     DANA
#
#                  ISO_TIME NATURE   LAT   LON WMO_WIND WMO_PRES WMO_AGENCY  \
# 0     1877-05-20 21:00:00     TS  22.8  87.1
# 1     1877-05-21 00:00:00     TS  23.3  87.2
# 2     1877-05-21 03:00:00     TS  23.6  87.3
# 3     1877-05-21 06:00:00     TS  23.8  87.4
# 4     1877-05-21 09:00:00     TS  24.0  87.4
# ...                   ...    ...   ...   ...      ...      ...        ...
# 6709  2024-09-15 21:00:00     TS  22.9  87.1
# 6710  2024-09-16 00:00:00     TS  23.0  87.0       30      990   newdelhi
# 6711  2024-10-24 15:00:00     TS  20.1  87.3       60      986   newdelhi
# 6712  2024-10-24 18:00:00     TS  20.5  87.1       55      988   newdelhi
# 6713  2024-10-24 21:00:00     TS  20.7  87.0       55      988   newdelhi
#
#      TRACK_TYPE  DIST2LAND LANDFALL            IFLAG  Haversine Distance
# 0          main          0        0  __________PP___           59.269827
# 1          main          0        0  __________OP___           56.531103
# 2          main          0        0  __________PO___           34.883381
# 3          main          0        0  __________OP___           24.458933
# 4          main          0        0  __________PP___           22.238985
# ...         ...        ...      ...              ...                 ...
# 6709       main          0        0  _____P_________           10.243114
# 6710       main          0        0  _____O_________           15.115788
# 6711       main         66       23  P____O_________           39.367274
# 6712       main         23        0  O____O_________           49.125664
# 6713       main          0        0  P____O_________           24.554212
#
# [6714 rows x 18 columns]

# %%
data['NAME'].unique()
# Out:
# array(['UNNAMED', 'WINNIE', 'BILLIE', 'HOPE', 'KIM', 'HERBERT', 'FORREST',
#        'AKASH', 'SIDR', 'RASHMI', 'BIJLI', 'AILA', 'MAHASEN:VIYARU',
#        'KOMEN', 'ROANU', 'MORA', 'TITLI', 'FANI', 'BULBUL:MATMO',
#        'AMPHAN', 'YAAS', 'JAWAD', 'SITRANG', 'MOCHA', 'HAMOON', 'MIDHILI',
#        'REMAL', 'DANA'], dtype=object)

# %%
len(data['NAME'].unique())
# Out:
# 28
